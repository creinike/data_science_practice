# %% [markdown]
# <center><u><H1>Activation Functions</H1></u></center>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z = np.linspace(-1,1,20)
print(z)
# Out:
# [-1.         -0.89473684 -0.78947368 -0.68421053 -0.57894737 -0.47368421
#  -0.36842105 -0.26315789 -0.15789474 -0.05263158  0.05263158  0.15789474
#   0.26315789  0.36842105  0.47368421  0.57894737  0.68421053  0.78947368
#   0.89473684  1.        ]

# %% [markdown]
# ## Identity Function:

# %%
def f(x):
    return x

# %%
ifunc = [f(x) for x in z]

# %%
plt.figure(figsize=(8,6))
plt.plot(z, ifunc, color='red',linewidth=2.0, label="Identity Function")
plt.xlabel("Z")
plt.ylabel("f(z)")
plt.legend(loc="best")

# %% [markdown]
# ## Step Function:

# %%
# This function activates the neuron if the activation if the activation
# is above a certain value that is called threshold activity function
def sf(x):
    if x >= 0:
        output = 1
    else:
        output = 0
    return output

# %%
sf_ = [sf(x) for x in z]

# %%
plt.figure(figsize=(6,6))
plt.plot(z, sf_, color='green',linewidth=2.0, label="Step Function")
plt.xlabel("Z")
plt.ylabel("f(z)")
plt.legend(loc="best")

# %% [markdown]
# ## Sigmoid Function:

# %%
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

# %%
X_sig = np.linspace(-10,10,100)

# %%
sigmoid_ = [sigmoid(x) for x in X_sig]

# %%
plt.figure(figsize=(8,6))
plt.plot(X_sig, sigmoid_, color='blue',linewidth=2.0, label="Sigmoid Function")
plt.xlabel("Z")
plt.ylabel("f(z)")
plt.legend(loc="best")

# %% [markdown]
# ## Hyperbolic Tangent:

# %%
ht = [np.tanh(x) for x in z]

# %%
plt.figure(figsize=(6,6))
plt.plot(z, ht, color='purple', linewidth=2.0, label="Hyberbolic Tangent Function")
plt.xlabel("Z")
plt.ylabel("f(z)")
plt.legend(loc="best")

# %% [markdown]
# ## ReLU (Rectified Linear Unit)

# %%
def relu(x):
    if x >= 0:
        output = x
    else:
        output = 0
    return output

# %%
relu_ = [relu(x) for x in z]

# %%
plt.figure(figsize=(8,6))
plt.plot(z, relu_, color='black',linewidth=2.0, label="ReLU Function")
plt.xlabel("Z")
plt.ylabel("f(z)")
plt.legend(loc="best")

# %% [markdown]
# ## Reference:
#
# ### https://en.wikipedia.org/wiki/Activation_function
# ### https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.tanh.html
