# %% [markdown]
# <center><u><H1>Matplotlib-Graphics Customization</H1></u></center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %% [markdown]
# ## Loading the data:

# %% [markdown]
# dataset: https://www.kaggle.com/shivachandel/kc-house-data

# %%
data = pd.read_csv('../data/kc_house_data.csv')
df = data.sample(100)
df.head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 6005   8947800080  20141105T000000  300000.0         3       1.00
# 9648   2310100180  20141107T000000  359950.0         3       2.50
# 3231   1924069058  20141010T000000  965000.0         4       3.25
# 4606   2767704345  20140520T000000  467000.0         3       2.25
# 13540  7857003953  20141020T000000  420000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 6005           970     12300     1.0           0     0  ...      7
# 9648          2210      6280     2.0           0     0  ...      8
# 3231          5010     49222     2.0           0     0  ...      9
# 4606          1270      1213     2.0           0     0  ...      8
# 13540         1940      5414     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 6005        970.0              0      1982             0    98028  47.7335
# 9648       2210.0              0      2003             0    98038  47.3500
# 3231       3710.0           1300      1978             0    98027  47.5489
# 4606       1040.0            230      2005             0    98107  47.6736
# 13540      1940.0              0      1997             0    98108  47.5461
#
#           long  sqft_living15  sqft_lot15
# 6005  -122.227           2040        9994
# 9648  -122.043           2250        5972
# 3231  -122.092           3140       54014
# 4606  -122.375           1410        1265
# 13540 -122.299           2050        6307
#
# [5 rows x 21 columns]

# %%
x = df['sqft_living']
y = df['price']

# %% [markdown]
# ## Visualizing the data with default Matplotlib

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(x, y, color='green')

# %% [markdown]
# ## Improving visualization:

# %%
# Remove Spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig

# %%
# Using Latex : www.latex-project.org
ax.set_title(r'House Size in $ft2$ vs. Price', fontsize=20, pad=20)
ax.set_xlabel('House Size', fontsize=16, labelpad=20)
ax.set_ylabel('Price', fontsize=16, labelpad=20)
fig

# %%
#Add units to Axis labels
y_format = '${x:,.2f}'
y_tick = mtick.StrMethodFormatter(y_format)
ax.yaxis.set_major_formatter(y_tick)

x_format = r'{x:,.0f} $ft^2$'
x_tick = mtick.StrMethodFormatter(x_format)
ax.xaxis.set_major_formatter(x_tick)
fig

# %%
# Change color, marker, size and transparency
ax.scatter(x, y, s=200, marker='+', color='#FF5733', alpha=0.8)
fig

# %%
# adding major gridlines
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
fig

# %%
# applying color maps
ax.scatter(x, y, s=300, c=y, marker='+', cmap='Greens', alpha=0.8)
fig

# %%
ax.scatter(x, y, s=300, c=y, marker='+', cmap='Reds', alpha=0.8)
ax.scatter(x, y, color='black')
fig

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.58331648],
#        [0.58331648, 1.        ]])

# %%
# Add legend: correlation coefficient
corr_ = np.round(np.corrcoef(x, y)[0][1], 2)
corr_
# Out:
# 0.58

# %%
ax.scatter(x, y, s=300, marker='o', color='black', alpha=0.5, label=f'Correlation: {corr_}')
ax.legend(fancybox=True, prop={'size': 14}, loc='best')
ax.scatter(x, y, color='w')
fig

# %% [markdown]
# ## References:
#
# www.latex-project.org
#
# https://htmlcolorcodes.com/
#
# https://matplotlib.org/examples/color/colormaps_reference.html
